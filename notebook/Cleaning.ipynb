# %%
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB
# ...

# %%
df['Released_Year'] = pd.to_numeric(df['Released_Year'], errors='coerce')

# %%
df['Released_Year'].head(10)
# Out:
# 0    1994.0
# 1    1972.0
# 2    2008.0
# 3    1974.0
# 4    1957.0
# 5    2003.0
# 6    1994.0
# 7    1993.0
# 8    2010.0
# 9    1999.0
# Name: Released_Year, dtype: float64

# %%
df['Runtime'] = df['Runtime'].str.replace(' min','').astype(float)
df['Runtime'].head()
# Out:
# 0    142.0
# 1    175.0
# 2    152.0
# 3    202.0
# 4     96.0
# Name: Runtime, dtype: float64

# %%
df['Certificate'] = df['Certificate'].fillna("Not Rated")
df['Certificate'].head()
# Out:
# 0     A
# 1     A
# 2    UA
# 3     A
# 4     U
# Name: Certificate, dtype: object

# %%
df['Certificate'].value_counts()
# Out:
# Certificate
# U            234
# A            197
# UA           175
# R            146
# Not Rated    101
# PG-13         43
# PG            37
# Passed        34
# G             12
# Approved      11
# TV-PG          3
# GP             2
# TV-14          1
# Unrated        1
# TV-MA          1
# 16             1
# U/A            1
# Name: count, dtype: int64

# %%
df['Gross'] = df['Gross'].replace(r'[\$,]', '', regex=True).astype(float)
df['Gross'].head(10)
# Out:
# 0     28341469.0
# 1    134966411.0
# 2    534858444.0
# 3     57300000.0
# 4      4360000.0
# 5    377845905.0
# 6    107928762.0
# 7     96898818.0
# 8    292576195.0
# 9     37030102.0
# Name: Gross, dtype: float64

# %%
df['Meta_score'] = df['Meta_score'].fillna(df['Meta_score'].mean())
df['Meta_score'].head(10)
# Out:
# 0     80.0
# 1    100.0
# 2     84.0
# 3     90.0
# 4     96.0
# 5     94.0
# 6     94.0
# 7     94.0
# 8     74.0
# 9     66.0
# Name: Meta_score, dtype: float64

# %%
df['Genre'] = df['Genre'].str.strip().str.title()
df['Director'] = df['Director'].str.strip()
df['Series_Title'] = df['Series_Title'].str.strip()
df['Main_Genre'] = df['Genre'].str.split(',').str[0]
df[['Series_Title','Genre','Main_Genre','Director']].head()
# Out:
#                Series_Title                 Genre Main_Genre  \
# 0  The Shawshank Redemption                 Drama      Drama
# 1             The Godfather          Crime, Drama      Crime
# 2           The Dark Knight  Action, Crime, Drama     Action
# 3    The Godfather: Part II          Crime, Drama      Crime
# 4              12 Angry Men          Crime, Drama      Crime
#
#                Director
# 0        Frank Darabont
# 1  Francis Ford Coppola
# 2     Christopher Nolan
# 3  Francis Ford Coppola
# 4          Sidney Lumet

# %%
print("Duplicates found:", df.duplicated().sum())
df = df.drop_duplicates()
# Out:
# Duplicates found: 0

# %%
df.to_csv("./data/imdb_top_1000_clean.csv", index=False)
print("✅ Cleaned dataset saved as imdb_top_1000_clean.csv")
# Out:
# ✅ Cleaned dataset saved as imdb_top_1000_clean.csv

# %%
df['Certificate'] = df['Certificate'].replace(['16', 'Passed'], 'Not Rated')
df['Certificate'].unique()
# Out:
# array(['A', 'UA', 'U', 'PG-13', 'R', 'Not Rated', 'PG', 'G', 'TV-14',
#        'TV-MA', 'Unrated', 'GP', 'Approved', 'TV-PG', 'U/A'], dtype=object)

# %%
df['Meta_score'] = df['Meta_score'].round(0).astype('Int64')
df['Meta_score'].head(10)
# Out:
# 0     80
# 1    100
# 2     84
# 3     90
# 4     96
# 5     94
# 6     94
# 7     94
# 8     74
# 9     66
# Name: Meta_score, dtype: Int64

# %%
df['Gross'] = df['Gross'].replace('[^0-9]', '', regex=True)
df['Gross'] = pd.to_numeric(df['Gross'], errors='coerce')
df['Gross'].head(20)
# Out:
# 0      28341469.0
# 1     134966411.0
# 2     534858444.0
# 3      57300000.0
# 4       4360000.0
# 5     377845905.0
# 6     107928762.0
# 7      96898818.0
# 8     292576195.0
# 9      37030102.0
# 10    315544750.0
# 11    330252182.0
# 12      6100000.0
# 13    342551365.0
# 14    171479930.0
# 15     46836394.0
# 16    290475067.0
# 17    112000000.0
# 18            NaN
# 19     53367844.0
# Name: Gross, dtype: float64

# %%
df.info()            
df.isnull().sum()     
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  999 non-null    float64
#  3   Certificate    1000 non-null   object
#  4   Runtime        1000 non-null   float64
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     1000 non-null   Int64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    float64
#  16  Main_Genre     1000 non-null   object
# ...

# %%
df.to_csv("./data/imdb_top_1000_clean.csv", index=False)

# %%
print("Before Cleaning (first 10 rows):")
print(df[['Series_Title', 'Star1']].head(10))

char_map = {
    "0": "o",
    "1": "i",
    "2": "z",
    "3": "e",
    "4": "a",
    "5": "s",
    "6": "g",
    "7": "v",
    "8": "b",
    "9": "g",
    "$": "s",
    "!": "i",
    "@": "a"
}

def normalize_text(text):
    if isinstance(text, str):
        return "".join(char_map.get(ch, ch) for ch in text)
    return text
df['Series_Title'] = df['Series_Title'].str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)
for col in ['Star1', 'Star2', 'Star3', 'Star4']:
    df[col] = df[col].apply(normalize_text)
    df[col] = df[col].str.replace(r'[^a-zA-Z\s]', '', regex=True)
print(df[['Series_Title', 'Star1', 'Star2', 'Star3', 'Star4']].head(15))
# Out:
# Before Cleaning (first 10 rows):
#                                    Series_Title              Star1
# 0                      The Shawshank Redemption        Tim Robbins
# 1                                 The Godfather      Marlon Brando
# 2                               The Dark Knight     Christian Bale
# 3                         The Godfather Part II          Al Pacino
# 4                                  iz Angry Men        Henry Fonda
# 5  The Lord of the Rings The Return of the King        Elijah Wood
# 6                                  Pulp Fiction      John Travolta
# 7                               Schindlers List        Liam Neeson
# 8                                     Inception  Leonardo DiCaprio
# 9                                    Fight Club          Brad Pitt
#                                         Series_Title              Star1  \
# 0                           The Shawshank Redemption        Tim Robbins
# ...

# %%
df = pd.read_csv("../data/imdb_top_1000.csv")

# %%
df.head(10)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5  https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6  https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7  https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8  https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9  https://m.media-amazon.com/images/M/MV5BMmEzNT...
#
#                                     Series_Title Released_Year Certificate  \
# 0                       The Shawshank Redemption          1994           A
# 1                                  The Godfather          1972           A
# 2                                The Dark Knight          2008          UA
# 3                         The Godfather: Part II          1974           A
# ...

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB
# ...

# %%
df['Released_Year'] = pd.to_numeric(df['Released_Year'], errors='coerce').astype('Int64')
df['Released_Year'].head()
# Out:
# 0    1994
# 1    1972
# 2    2008
# 3    1974
# 4    1957
# Name: Released_Year, dtype: Int64

# %%
df['Runtime'] = df ['Runtime'].astype(str)
df['Runtime'] = df ['Runtime'].str.replace("min","")
df['Runtime'] = pd.to_numeric(df['Runtime'], errors='coerce')

# %%
df['Runtime'].head(10)
# Out:
# 0    142.0
# 1    175.0
# 2    152.0
# 3    202.0
# 4     96.0
# 5    201.0
# 6    154.0
# 7    195.0
# 8    148.0
# 9    139.0
# Name: Runtime, dtype: float64

# %%
df['Certificate'] = df['Certificate'].fillna("Not Rated")
df['Certificate'].head()
# Out:
# 0     A
# 1     A
# 2    UA
# 3     A
# 4     U
# Name: Certificate, dtype: object

# %%
df['Certificate'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0              A
# 1              A
# 2             UA
# 3              A
# 4              U
#          ...
# 995            A
# 996            G
# 997       Passed
# 998    Not Rated
# 999    Not Rated
# Name: Certificate, Length: 1000, dtype: object>

# %%
df['Gross'] = df['Gross'].replace(r'[\$,]', '', regex=True).astype(float)
df['Gross'].head(10)
# Out:
# 0     28341469.0
# 1    134966411.0
# 2    534858444.0
# 3     57300000.0
# 4      4360000.0
# 5    377845905.0
# 6    107928762.0
# 7     96898818.0
# 8    292576195.0
# 9     37030102.0
# Name: Gross, dtype: float64

# %%
df['Meta_score'] = df['Meta_score'].fillna(df['Meta_score'].mean())
df['Meta_score'].head(10)
# Out:
# 0     80.0
# 1    100.0
# 2     84.0
# 3     90.0
# 4     96.0
# 5     94.0
# 6     94.0
# 7     94.0
# 8     74.0
# 9     66.0
# Name: Meta_score, dtype: float64

# %%
df['Genre'] = df['Genre'].str.strip().str.title()
df['Director'] = df['Director'].str.strip()
df['Series_Title'] = df['Series_Title'].str.strip()
df['Main_Genre'] = df['Genre'].str.split(',').str[0]
df[['Series_Title','Genre','Main_Genre','Director']].head()
# Out:
#                Series_Title                 Genre Main_Genre  \
# 0  The Shawshank Redemption                 Drama      Drama
# 1             The Godfather          Crime, Drama      Crime
# 2           The Dark Knight  Action, Crime, Drama     Action
# 3    The Godfather: Part II          Crime, Drama      Crime
# 4              12 Angry Men          Crime, Drama      Crime
#
#                Director
# 0        Frank Darabont
# 1  Francis Ford Coppola
# 2     Christopher Nolan
# 3  Francis Ford Coppola
# 4          Sidney Lumet

# %%
char_map = {
    "0": "o",
    "1": "i",
    "2": "z",
    "3": "e",
    "4": "a",
    "5": "s",
    "6": "g",
    "7": "v",
    "8": "b",
    "9": "g",
    "$": "s",
    "!": "i",
    "@": "a"
}
def normalize_text(text):
    if isinstance(text, str):
        return "".join(char_map.get(ch, ch) for ch in text)
    return text

df['Series_Title'] = df['Series_Title'].str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)

for col in ['Star1', 'Star2', 'Star3', 'Star4']:
    df[col] = df[col].apply(normalize_text)
    df[col] = df[col].str.replace(r'[^a-zA-Z\s]', '', regex=True)
    print(df[['Series_Title', 'Star1', 'Star2', 'Star3', 'Star4']].head(15))
# Out:
#                                         Series_Title              Star1  \
# 0                           The Shawshank Redemption        Tim Robbins
# 1                                      The Godfather      Marlon Brando
# 2                                    The Dark Knight     Christian Bale
# 3                              The Godfather Part II          Al Pacino
# 4                                       12 Angry Men        Henry Fonda
# 5       The Lord of the Rings The Return of the King        Elijah Wood
# 6                                       Pulp Fiction      John Travolta
# 7                                    Schindlers List        Liam Neeson
# 8                                          Inception  Leonardo DiCaprio
# 9                                         Fight Club          Brad Pitt
# 10  The Lord of the Rings The Fellowship of the Ring        Elijah Wood
# 11                                      Forrest Gump          Tom Hanks
# ...

# %%
df.to_csv("../data/imdb_top_1000_newclean.csv", index=False)

# %%
df['Meta_score'] = df['Meta_score'].astype(int)
df['Meta_score'].head(30)
# Out:
# 0      80
# 1     100
# 2      84
# 3      90
# 4      96
# 5      94
# 6      94
# 7      94
# 8      74
# 9      66
# 10     92
# 11     82
# 12     90
# 13     87
# 14     73
# 15     90
# 16     82
# 17     83
# 18     90
# 19     96
# 20     77
# 21     74
# 22     79
# 23     96
# 24     91
# 25     61
# 26     59
# 27     65
# 28     85
# 29     90
# Name: Meta_score, dtype: int64

# %%
df.to_csv("../data/imdb_top_1000_newclean.csv", index=False)
